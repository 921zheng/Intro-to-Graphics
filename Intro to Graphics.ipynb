# %%
import pandas as pd
# %matplotlib inline

# %% [markdown]
# ### Plotting with Pandas

# %%
df=pd.DataFrame()
df['Values']=[100,231,222,124,142,44,321,321]
df['t']=[i+1 for i in range(8)]
df
# Out:
#    Values  t
# 0     100  1
# 1     231  2
# 2     222  3
# 3     124  4
# 4     142  5
# 5      44  6
# 6     321  7
# 7     321  8

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.plot(y='Values', x='t')
# Out:
# <Axes: xlabel='t'>

# %%
[attr for attr in dir(df.plot) if not attr.startswith('_')]
# Out:
# ['area',
#  'bar',
#  'barh',
#  'box',
#  'density',
#  'hexbin',
#  'hist',
#  'kde',
#  'line',
#  'pie',
#  'scatter']

# %%
df.plot.area(y='Values', x='t')
# Out:
# <Axes: xlabel='t'>

# %%
df.plot.bar(y='Values', x='t')
# Out:
# <Axes: xlabel='t'>

# %%
df.plot.barh(y='Values', x='t')
# Out:
# <Axes: ylabel='t'>

# %%
df.plot.box(y='Values', x='t')
# Out:
# <Axes: >

# %%
df.plot.density(y='Values', x='t')
# Out:
# <Axes: ylabel='Density'>

# %%
df.plot.hist(y='Values', x='t')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot.pie(y='Values', x='t')
# Out:
# <Axes: ylabel='Values'>

# %%
df.plot.scatter(y='Values', x='t')
# Out:
# <Axes: xlabel='t', ylabel='Values'>
